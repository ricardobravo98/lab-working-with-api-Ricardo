# %% [markdown]
# ### Trying Skyscanner Endpoint

# %%
import requests

url = "https://skyscanner50.p.rapidapi.com/api/v1/searchAirport"

querystring = {"query":"london"}

headers = {
	"X-RapidAPI-Key": "",
	"X-RapidAPI-Host": "skyscanner50.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'message': 'Success', 'timestamp': 1687805608251, 'data': [{'PlaceId': 'LOND', 'PlaceName': 'London', 'LocalizedPlaceName': '', 'CountryId': 'UK', 'CityId': 'LOND', 'IataCode': 'LON', 'CountryName': 'United Kingdom', 'PlaceNameEn': '', 'CityName': 'London', 'CityNameEn': '', 'GeoId': '27544008', 'GeoContainerId': '27544008', 'Location': '51.5041174139,-0.0943465343', 'ResultingPhrase': 'London|England|United Kingdom', 'UntransliteratedResultingPhrase': 'London|England|United Kingdom'}, {'PlaceId': 'LHR', 'PlaceName': 'London Heathrow', 'LocalizedPlaceName': '', 'CountryId': 'UK', 'CityId': 'LOND', 'IataCode': '', 'CountryName': 'United Kingdom', 'PlaceNameEn': '', 'CityName': 'London', 'CityNameEn': '', 'GeoId': '95565050', 'GeoContainerId': '27544008', 'Location': '51.471389,-0.452778', 'ResultingPhrase': 'London Heathrow (LHR), London|England|United Kingdom', 'UntransliteratedResultingPhrase': 'London Heathrow (LHR), London|England|United Kingdom'}, {'PlaceId': 'ST
# ...

# %%
import requests

url = "https://partners.api.skyscanner.net/apiservices/v3/flights/indicative/search"

querystring = {"query":"london"}

headers = {
	"X-RapidAPI-Key": "",
	"X-RapidAPI-Host": "skyscanner50.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'code': 12, 'message': 'Method Not Allowed', 'details': []}

# %%
import pandas as pd

output= response.json()
results = output['data']

# %%
df = pd.DataFrame(results)
df
# Out:
#   PlaceId        PlaceName LocalizedPlaceName CountryId CityId IataCode  \
# 0    LOND           London                           UK   LOND      LON
# 1     LHR  London Heathrow                           UK   LOND
# 2     STN  London Stansted                           UK   LOND
# 3     LGW   London Gatwick                           UK   LOND
# 4     LTN     London Luton                           UK   LOND
# 5     LCY      London City                           UK   LOND
# 6     SEN  London Southend                           UK   LOND
# 7     YXU           London                           CA   YXUS
# 8     ELS      East London                           ZA   ELSA
# 9     LOZ    Corbin-London                           US   LOZA
#
#       CountryName PlaceNameEn     CityName CityNameEn      GeoId  \
# 0  United Kingdom                   London              27544008
# 1  United Kingdom                   London              95565050
# ...

# %% [markdown]
# ### this is an APi that just gives me locations, I am sorry I couldn´t extract the ones with the prices, I have had no time

# %% [markdown]
# ### Trying with a different endpoint

# %%
import requests

url = "https://skyscanner50.p.rapidapi.com/api/v1/getFlightDetails"

querystring = {"itineraryId":"<REQUIRED>","legs":"[{\"origin\":\"LOND\",\"destination\":\"NYCA\",\"date\":\"2023-02-07\"},{\"date\":\"2023-02-14\",\"destination\":\"LOND\",\"origin\":\"NYCA\"}]","adults":"1","currency":"USD","countryCode":"US","market":"en-US"}

headers = {
	"X-RapidAPI-Key": "",
	"X-RapidAPI-Host": "skyscanner50.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'messages': 'The request to the API has timed out. Please try again later, or if the issue persists, please contact the API provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (took too long to respond)'}

# %%
### I received an error I don´t know why
